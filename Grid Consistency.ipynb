# %%
import numpy as np
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import pandas as pd

# %%
SLA=Dataset('../copernicus/cmems_obs-sl_glo_phy-ssh_my_allsat-l4-duacs-0.25deg_P1D_1704119807053.nc')

# %%
maplat=SLA.variables['latitude'][:]
maplon=SLA.variables['longitude'][:]

# %% [markdown]
# # Test Data

# %%
grid_acs_test=np.load('grid_acs_test.npy')
grid_acl_test=np.load('grid_acl_test.npy')
grid_cs_test=np.load('grid_cs_test.npy')
grid_cl_test=np.load('grid_cl_test.npy')

# %%
plt.pcolormesh(maplon,maplat,grid_acl_test[0])
plt.colorbar()

# %%
plt.pcolormesh(maplon,maplat,grid_acs_test[0])
plt.colorbar()

# %%
plt.pcolormesh(maplon,maplat,grid_cl_test[0])
plt.colorbar()

# %%
plt.pcolormesh(maplon,maplat,grid_cs_test[0])
plt.colorbar()

# %%
grid_all_test=grid_acs_test+grid_acl_test+grid_cs_test+grid_cl_test
np.save('grid_all_test',grid_all_test)

# %%
plt.pcolormesh(maplon,maplat,grid_all_test[114])
plt.colorbar()

# %%
plt.pcolormesh(maplon,maplat,grid_all_test[364])
plt.colorbar()

# %% [markdown]
# # Train Data

# %%
grid_acs=np.load('grid_acs.npy')
grid_acl=np.load('grid_acl.npy')
grid_cs=np.load('grid_cs.npy')
grid_cl=np.load('grid_cl.npy')

# %%
plt.pcolormesh(maplon,maplat,grid_acl[0])
plt.colorbar()

# %%
plt.pcolormesh(maplon,maplat,grid_acs[0])
plt.colorbar()

# %%
plt.pcolormesh(maplon,maplat,grid_cl[0])
plt.colorbar()

# %%
plt.pcolormesh(maplon,maplat,grid_cs[0])
plt.colorbar()

# %%
grid_all=grid_acs+grid_acl+grid_cs+grid_cl
np.save('grid_all',grid_all)

# %%
plt.pcolormesh(maplon,maplat,grid_all[114])
plt.colorbar()

# %%
plt.pcolormesh(maplon,maplat,grid_all[514])
plt.colorbar()

# %% [markdown]
# # Get ADT Data

# %%
SLA=Dataset('../copernicus/cmems_obs-sl_glo_phy-ssh_my_allsat-l4-duacs-0.25deg_P1D_1704119807053.nc')
adt=SLA.variables['adt'][:]

# %%
adt=np.array(adt)
np.save('adt_train',adt)

# %%
plt.pcolormesh(maplon,maplat,adt[114])
plt.colorbar()

# %%
plt.pcolormesh(maplon,maplat,adt[514])
plt.colorbar()

# %%
SLA_test=Dataset('../copernicus/cmems_obs-sl_glo_phy-ssh_my_allsat-l4-duacs-0.25deg_P1D_1704485888634.nc')
adt_test=SLA_test.variables['adt'][:]

# %%
adt_test=np.array(adt_test)
np.save('adt_test',adt_test)

# %%
plt.pcolormesh(maplon,maplat,adt_test[114])
plt.colorbar()

# %%
plt.pcolormesh(maplon,maplat,adt_test[364])
plt.colorbar()
